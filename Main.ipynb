# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mat = pd.read_csv("student-mat.csv",sep=";")
por = pd.read_csv("student-por.csv",sep=";")

# %%
mat.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1   at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1   at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2    health  services ...
# 4     GP   F   16       U     GT3       T     3     3     other     other ...
# 5     GP   M   16       U     LE3       T     4     3  services     other ...
# 6     GP   M   16       U     LE3       T     2     2     other     other ...
# 7     GP   F   17       U     GT3       A     4     4     other   teacher ...
# 8     GP   M   15       U     LE3       A     3     2  services     other ...
# 9     GP   M   15       U     GT3       T     3     4     other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
mat.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
mat["Mjob"].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
moda = mat["Medu"].mode()
print "moda=%d"%moda
# Out:
# moda=4

# %%
media = mat["age"].mean()
print "media=%f"%media
# Out:
# media=16.696203

# %%
maximanota = mat["G3"].max()
promedio = mat["G3"].mean()
minimanota = mat["G3"].min()
print "La maxima nota es %d la minima es %d el promedio es %f "%(maximanota,minimanota,promedio)
# Out:
# La maxima nota es 20 la minima es 0 el promedio es 10.415190

# %%
mediana = mat["G3"].median()
print "La mediana de las notas finales es %d"%mediana
# Out:
# La mediana de las notas finales es 11

# %%
varianza = mat["age"].var()
sd = mat["age"].std()
print "La varianza de la variable Edades es %f y la desviacion estandar %f"%(varianza,sd)
# Out:
# La varianza de la variable Edades es 1.628285 y la desviacion estandar 1.276043

# %%
mat.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
mat["freetime"].hist(bins=50)

# %%
plt.scatter(mat["absences"],mat["G3"])

# %%
GP = mat[mat["school"]=="GP"]
mediagp = GP["G3"].mean()
MS = mat[mat["school"]=="MS"]
mediams = MS["G3"].mean()
cont1 = 0
cont2 = 0
for nota in GP["G3"]:
    if nota>=9.5:
        cont1=cont1+1
for nota in MS["G3"]:
    if nota>=9.5:
        cont2=cont2+1
porc1=(cont1*100)/len(GP["G3"])        
porc2=(cont2*100)/len(MS["G3"]) 
print "La nota media en los estudiantes de la ecuela GP es %f y el porcentaje de aprobados %f , y en la escuela MS es %f el porcentaje de aprobados es %f"%(mediagp,porc1,mediams,porc2)
# Out:
# La nota media en los estudiantes de la ecuela GP es 10.489971 y el porcentaje de aprobados 67.000000 , y en la escuela MS es 9.847826 el porcentaje de aprobados es 63.000000

# %%
hg = mat[mat["higher"]=="yes"]
nhg = mat[mat["higher"]=="no"]
media1 = hg["G3"].mean()
media2 = nhg["G3"].mean()
print "La nota media de los estudiantes que tienen interes en realizar estudios superiores es %f , y en los estudiantes que no tienen interes es %f"%(media1,media2)
# Out:
# La nota media de los estudiantes que tienen interes en realizar estudios superiores es 10.608000 , y en los estudiantes que no tienen interes es 6.800000
